# %%
# !pip install -q ctransformers langchain

# %%
from langchain.llms import CTransformers 
from langchain import PromptTemplate, LLMChain
from langchain.callbacks.streaming_stdout import StreamingStdOutCallbackHandler

# %%
llm = CTransformers(
    model = "TheBloke/Llama-2-7B-Chat-GGML",
    model_file = "llama-2-7b-chat.ggmlv3.q2_K.bin",
    callbacks = [StreamingStdOutCallbackHandler()]
)
# Out:
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading (…)ab11864b/config.json:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# Fetching 1 files:   0%|          | 0/1 [00:00<?, ?it/s]
# Downloading (…)chat.ggmlv3.q2_K.bin:   0%|          | 0.00/2.87G [00:00<?, ?B/s]

# %%
template = """
[INST] <<SYS>>
You are a helpful, respectful and honest assistant. Your answers are always brief.
<</SYS>>
{text}[/INST]
"""

prompt = PromptTemplate(
    template=template, 
    input_variables=["text"]
)

# %%
llm_chain = LLMChain(
    prompt = prompt,
    llm = llm
)

# %%
response = llm_chain.run("What is the capital of Egypt?")
# Out:
# The capital of Egypt is Cairo.

# %%
response = llm_chain.run("Why some days are terrible?")
# Out:
# There are several reasons why some days can be terrible:
#
# 1. Lack of motivation or purpose: When an individual lacks direction or meaning in their life, they may feel unmotivated and disconnected from the world around them.
# 2. Negative thinking patterns: Often, people's negative thoughts and beliefs can create a self-fulfilling prophecy, where their pessimistic expectations come true.
# 3. Unrealistic expectations: When individuals have unrealistic expectations of themselves or the world around them, they may experience disappointment and frustration when those expectations are not met.
# 4. Trauma or stress: Traumatic events or chronic stress can make a person feel overwhelmed, anxious, or depressed, causing feelings of hopelessness and despair.
# 5. Lack of social support: Feeling isolated, disconnected from others, or lacking emotional support can contribute to feeling down or terrible on some days.
#
# It is important to remember that everyone experiences challenging days at some point in their lives, and it is okay to not feel okay all the time. It is essential to prioritize self-care, seek social
